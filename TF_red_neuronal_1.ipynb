# %% [markdown]
# <a href="https://colab.research.google.com/github/andresvillamayor/redes-neuronales/blob/main/TF_red_neuronal_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import tensorflow as tf

# %%
def f(x):
  return x + 5
xs = np.arange(0,10,0.5)
ys = f(xs)

# %%
# reset de la sesión, en caso de querer reentrenar el modelo
tf.keras.backend.clear_session()

# %%
model = tf.keras.Sequential([tf.keras.layers.Dense(units=1, input_shape=[1])])

# %%
model.compile(optimizer='sgd', loss='mse')

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense (Dense)                (None, 1)                 2
# ...
# Total params: 2
# Trainable params: 2
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(xs, ys, epochs=500)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 447ms/step - loss: 202.8170
# Epoch 2/500
# 1/1 [==============================] - 0s 4ms/step - loss: 32.3344
# Epoch 3/500
# 1/1 [==============================] - 0s 4ms/step - loss: 9.2257
# Epoch 4/500
# 1/1 [==============================] - 0s 6ms/step - loss: 6.0494
# Epoch 5/500
# 1/1 [==============================] - 0s 4ms/step - loss: 5.5695
# Epoch 6/500
# 1/1 [==============================] - 0s 4ms/step - loss: 5.4547
# Epoch 7/500
# 1/1 [==============================] - 0s 4ms/step - loss: 5.3899
# Epoch 8/500
# 1/1 [==============================] - 0s 3ms/step - loss: 5.3323
# Epoch 9/500
# 1/1 [==============================] - 0s 3ms/step - loss: 5.2762
# Epoch 10/500
# 1/1 [==============================] - 0s 3ms/step - loss: 5.2208
# Epoch 11/500
# 1/1 [==============================] - 0s 4ms/step - loss: 5.1661
# Epoch 12/500
# 1/1 [==============================] - 0s 3ms/step - loss: 5.1119
# ...

# %%
print(model.predict([5]))
# Out:
# [[9.92588]]
